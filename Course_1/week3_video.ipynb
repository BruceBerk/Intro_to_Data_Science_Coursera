# %%
import pandas as pd
import numpy as np

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                        {'Name': 'Sally', 'Role': 'Course Liason', 'Location': 'Washington Ave'},
                        {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Ave'}])
staff_df
# Out:
#     Name            Role        Location
# 0  Kelly  Director of HR    State Street
# 1  Sally   Course Liason  Washington Ave
# 2  James          Grader  Washington Ave

# %%
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Ave'},
                        {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                        {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
student_df
# Out:
#     Name       School              Location
# 0  James     Business     1024 Billiard Ave
# 1   Mike          Law  Fraternity House #22
# 2  Sally  Engineering   512 Wilson Crescent

# %% [markdown]
# ## For staff, location is their office building. For students, it is their home address.
# ## Merge will preserve the data, appending _x and _y to indicate which DF the data came from.

# %%
pd.merge(staff_df, student_df, how='left', on='Name')
# Out:
#     Name            Role      Location_x       School           Location_y
# 0  Kelly  Director of HR    State Street          NaN                  NaN
# 1  Sally   Course Liason  Washington Ave  Engineering  512 Wilson Crescent
# 2  James          Grader  Washington Ave     Business    1024 Billiard Ave

# %% [markdown]
# ## here is multi-level merging

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Green', 'Role': 'Director of HR'},
                        {'First Name': 'Sally', 'Last Name': 'Ride', 'Role': 'Course Liason'},
                        {'First Name': 'James', 'Last Name': 'Kirk', 'Role': 'Grader'}])
staff_df
# Out:
#   First Name Last Name            Role
# 0      Kelly     Green  Director of HR
# 1      Sally      Ride   Course Liason
# 2      James      Kirk          Grader

# %%
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Etta', 'School': 'Business'},
                        {'First Name': 'Mike', 'Last Name': 'Hammer', 'School': 'Law'},
                        {'First Name': 'Sally', 'Last Name': 'Ride', 'School': 'Engineering'}])
student_df
# Out:
#   First Name Last Name       School
# 0      James      Etta     Business
# 1       Mike    Hammer          Law
# 2      Sally      Ride  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', on=['First Name', 'Last Name'])
# Out:
#   First Name Last Name           Role       School
# 0      Sally      Ride  Course Liason  Engineering

# %%
pd.merge(staff_df, student_df, how='right', on=['First Name', 'Last Name'])
# Out:
#   First Name Last Name           Role       School
# 0      James      Etta            NaN     Business
# 1       Mike    Hammer            NaN          Law
# 2      Sally      Ride  Course Liason  Engineering

# %%
pd.merge(student_df, staff_df, how='outer', on=['First Name', 'Last Name'])
# Out:
#   First Name Last Name       School            Role
# 0      James      Etta     Business             NaN
# 1       Mike    Hammer          Law             NaN
# 2      Sally      Ride  Engineering   Course Liason
# 3      Kelly     Green          NaN  Director of HR
# 4      James      Kirk          NaN          Grader

# %% [markdown]
# ## Group By

# %%
# census data
df = pd.read_csv('datasets/census.csv')

# %% [markdown]
# ### We want the average population for each county (SUMLEV 50) in each state

# %%
df = df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %% [markdown]
# ### Brute force method

# %%
# lets time 3 runs

# %%
# %%timeit -n 3

for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state +
         ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
# now let's use groupby()

# %%
# %%timeit -n 3

for group, frame in df.groupby('STNAME'):
    # groupby returns a tuple - the key (in this case the state) and the associated data frame
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group +
         ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
# 509 ms versus 13.9 ms - wow!

# %%
# you can use a function with group by
# for example - have a function which returns a batch number (0, 1, or 2) based on the first 
# letter of the state name.
# for the function approach to work, you have to be indexing on the column you are working with

# if no column is passed to groupby, then the index is used
df = df.set_index('STNAME')

def set_batch_number(item):
    if item[0] < 'M':
        return 0
    elif item[0] < 'Q':
        return 1
    return 2

for group, frame in df.groupby(set_batch_number):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing')
# Out:
# There are 1177 records in group 0 for processing
# There are 1134 records in group 1 for processing
# There are 831 records in group 2 for processing

# %%
# an example using Airbnb listings
df = pd.read_csv('datasets/listings.csv')
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
# we want to group by cancellation_policy and review_scores_value
df = df.set_index(['cancellation_policy', 'review_scores_value'])

# with a multi-index, pass the levels you are interested in to groupby
for group, frame in df.groupby(level=(0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %%
# this works, but what if we wanted to group by cancellation_policy and review_scores_value
# but want to separate out the 10s from those under 10?
# we would use a function
def grouping_fun(item):
    # the item is a tuple
    if item[1] == 10.0:
        return (item[0], "10.0")
    else:
        return (item[0], "not 10.0")
    
for group, frame in df.groupby(by=grouping_fun):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %% [markdown]
# ### In the split-apply-combine pattern, there are 3 types of data processing that happens during the apply step
# ### aggregation, transformation, filtration

# %% [markdown]
# ### Aggregation

# %%
# We use the method agg() on the groupby object, passing in a dictionary of the columns we are interested 
# in aggregation along with a function to apply to the aggregate.

# reset the index on our Airbnb data
df = df.reset_index()

df.groupby('cancellation_policy').agg({'review_scores_value': np.average})
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                             NaN
# moderate                             NaN
# strict                               NaN
# super_strict_30                      NaN

# %%
# oops! np.average doesn't exclude NaNs
# we can use a different function that does

df.groupby('cancellation_policy').agg({'review_scores_value': np.nanmean})
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                        9.237421
# moderate                        9.307398
# strict                          9.081441
# super_strict_30                 8.537313

# %%
# we can have multiple functions working on multiple columns
df.groupby('cancellation_policy').agg({'review_scores_value': (np.nanmean, np.nanstd),
                                      'reviews_per_month': np.nanmean})
# Out:
#                     review_scores_value           reviews_per_month
#                                 nanmean    nanstd           nanmean
# cancellation_policy
# flexible                       9.237421  1.096271          1.829210
# moderate                       9.307398  0.859859          2.391922
# strict                         9.081441  1.040531          1.873467
# super_strict_30                8.537313  0.840785          0.340143

# %% [markdown]
# ### Transformation

# %%
# agg() returns a single value per column, so one row per group. 
# transform() returns an object that is the same size as the group. It essentially broadcasts the function
# over the group dataframe, returning a new dataframe.

# %%
# Suppose we want to include the average ratings score for each cancellation policy group (like before)
# but we want to preserve the dataframe shape so we can generate a difference between the observation and
# the average

cols = ['cancellation_policy', 'review_scores_value']

# transform it and store it in a new dataframe
transform_df = df[cols].groupby('cancellation_policy').transform(np.nanmean)
transform_df.head(7)
# Out:
#    review_scores_value
# 0             9.307398
# 1             9.307398
# 2             9.307398
# 3             9.307398
# 4             9.237421
# 5             9.237421
# 6             9.081441

# %%
# rename the column, then add it back to the df
transform_df.rename({'review_scores_value': 'mean_review_score'}, axis='columns', inplace=True)
df = df.merge(transform_df, left_index=True, right_index=True)
df.head()
# Out:
#   cancellation_policy  review_scores_value        id  \
# 0            moderate                  NaN  12147973
# 1            moderate                  9.0   3075044
# 2            moderate                 10.0      6976
# 3            moderate                 10.0   1436513
# 4            flexible                 10.0   7651065
#
#                              listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1   https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 2      https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 3   https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 4   https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
#
#                                             name  \
# 0                     Sunny Bungalow in the City
# 1              Charming room in pet friendly apt
# 2               Mexican Folk Art Haven in Boston
# ...

# %%
# create a column that is the diff between the review score and the avg score for that cancellation policy group
df['mean_diff'] = np.absolute(df['review_scores_value'] - df['mean_review_score'])
df['mean_diff'].head(7)
# Out:
# 0         NaN
# 1    0.307398
# 2    0.692602
# 3    0.692602
# 4    0.762579
# 5    0.762579
# 6    0.081441
# Name: mean_diff, dtype: float64

# %% [markdown]
# ### Filtering

# %%
# the filter() function takes a function which it applies to each group dataframe and returns either
# True or False, depending on whether that group should be included in the results

# %%
# for instance, if we only want groups that have a mean rating above 9 to be included
df.groupby('cancellation_policy').filter(lambda x: np.nanmean(x['review_scores_value']) > 9.2)
# Out:
#      cancellation_policy  review_scores_value        id  \
# 0               moderate                  NaN  12147973
# 1               moderate                  9.0   3075044
# 2               moderate                 10.0      6976
# 3               moderate                 10.0   1436513
# 4               flexible                 10.0   7651065
# ...                  ...                  ...       ...
# 3576            flexible                  NaN  14689681
# 3577            flexible                  NaN  13750763
# 3579            flexible                  NaN  14852179
# 3582            flexible                  NaN  14585486
# 3584            flexible                  NaN  14504422
#
#                                 listing_url       scrape_id last_scraped  \
# 0     https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1      https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# ...

# %% [markdown]
# ### Apply

# %%
# apply() allows you to apply an arbitrary function to each group and stitch the results back 
# together for each apply into a single data frame where the index is preserved. 

# start with a clean dataframe
df = pd.read_csv('datasets/listings.csv')
df = df[['cancellation_policy', 'review_scores_value']]
df.head()
# Out:
#   cancellation_policy  review_scores_value
# 0            moderate                  NaN
# 1            moderate                  9.0
# 2            moderate                 10.0
# 3            moderate                 10.0
# 4            flexible                 10.0

# %%
# in the previous example, we calculated the mean review score for each cancellation policy and calculated the
# difference each review score was from the group mean. It was a two-step process. By using apply() we can
# do it in one step.

def calc_mean_review_scores(group):
    # group is a dataframe of just whatever we have grouped by
    avg = np.nanmean(group['review_scores_value'])

    # now broadcast our formula and create a new column
    group['review_scores_mean_diff'] = np.abs(avg - group['review_scores_value'])
    return group

# now just apply this to the groups
df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()
# Out:
#   cancellation_policy  review_scores_value  review_scores_mean_diff
# 0            moderate                  NaN                      NaN
# 1            moderate                  9.0                 0.307398
# 2            moderate                 10.0                 0.692602
# 3            moderate                 10.0                 0.692602
# 4            flexible                 10.0                 0.762579
